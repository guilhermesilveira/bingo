# %%
from tqdm import tqdm
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from bingo import *
from graph import *
from counting import *
from latex import *
from parallel import *

# %%
RUNS = 5_000_000
DECKS=[1,2,3,4,5,10,15,20,25,30,35,40]
palette = colorblind_palette(len(DECKS))

# %%
np.random.seed(56734)

# %%
# %%time

df_jokers_3_20 = quick_deck_matches_on(RUNS, decks=DECKS, accept_jokers=True, early_stop=3, discard=20)
# Out:
# CPU times: user 252 ms, sys: 668 ms, total: 921 ms
# Wall time: 4min 40s

# %%
ax, data_3_20 = print_cumulative(df_jokers_3_20, xticks=[21, 22, 23])
for i, (decks, card, values) in data_3_20.query("card==23").iterrows():
  print(decks, card, values, confidence(values * RUNS / 100, RUNS))
prob_table_to_latex(partial_card_to_prob(data_3_20.query("card==23"), RUNS), name="the-naturally-ocurring-bingo-miracle3-20")
# Out:
# 1.0 23.0 15.94002 (0.1590796057234577, 0.1597213176554168)
# 2.0 23.0 29.349220000000003 (0.29309321641595293, 0.29389150091194893)
# 3.0 23.0 40.58894 (0.40545903647852516, 0.4063199081354761)
# 4.0 23.0 50.08556 (0.5004173308290724, 0.5012938678561794)
# 5.0 23.0 58.04404 (0.5800077779989473, 0.5808728983932113)
# 10.0 23.0 82.39798 (0.8236457324575558, 0.8243133697025069)
# 15.0 23.0 92.59519999999999 (0.9257221518279818, 0.9261811936376393)
# 20.0 23.0 96.89636 (0.9688112334085339, 0.9691152459637935)
# 25.0 23.0 98.70411999999999 (0.9869416914771367, 0.9871399601164483)
# 30.0 23.0 99.45848 (0.9945200910247848, 0.994648748977012)
# 35.0 23.0 99.76863999999999 (0.9976439032808367, 0.9977281319549207)
# 40.0 23.0 99.90282 (0.9990005022278907, 0.9990551309460053)
# \begin{table}[tb]
# \label{tbl:the-naturally-ocurring-bingo-miracle3-20}
# \begin{tabular}{llll}
# \toprule
#  & Probability & CI lower & CI upper \\
# Decks &  &  &  \\
# \midrule
# 1 & 15.940% & 15.908% & 15.972% \\
# 2 & 29.349% & 29.309% & 29.389% \\
# 3 & 40.589% & 40.546% & 40.632% \\
# 4 & 50.086% & 50.042% & 50.129% \\
# 5 & 58.044% & 58.001% & 58.087% \\
# 10 & 82.398% & 82.365% & 82.431% \\
# 15 & 92.595% & 92.572% & 92.618% \\
# 20 & 96.896% & 96.881% & 96.912% \\
# 25 & 98.704% & 98.694% & 98.714% \\
# 30 & 99.458% & 99.452% & 99.465% \\
# 35 & 99.769% & 99.764% & 99.773% \\
# 40 & 99.903% & 99.900% & 99.906% \\
# \bottomrule
# \end{tabular}
# \end{table}
