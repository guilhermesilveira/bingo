# %%
from tqdm import tqdm
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from bingo import *
from graph import *
from counting import *
from latex import *
from parallel import *

# %%
RUNS = 5_000_000
DECKS=[1,2,3,4,5,10,15,20,25,30,35,40]
palette = colorblind_palette(len(DECKS))

# %%
np.random.seed(56734)

# %%
# %%time

df_jokers_3_20 = quick_deck_matches_on(RUNS, decks=DECKS, accept_jokers=True, early_stop=3, discard=20)
# Out:
# CPU times: user 287 ms, sys: 671 ms, total: 958 ms
# Wall time: 4min 39s

# %%
ax, data_3_20 = print_cumulative(df_jokers_3_20, xticks=[21, 22, 23])
for i, (decks, card, values) in data_3_20.query("card==23").iterrows():
  print(decks, card, values, confidence(values * RUNS / 100, RUNS))
prob_table_to_latex(partial_card_to_prob(data_3_20.query("card==23"), RUNS), name="the-naturally-ocurring-bingo-miracle3-20")
# Out:
# 1.0 23.0 15.946860000000001 (0.1591479498945039, 0.1597897733792645)
# 2.0 23.0 29.35416 (0.2931425967437373, 0.29394092050825466)
# 3.0 23.0 40.58574 (0.4054270418795924, 0.4062879027835812)
# 4.0 23.0 50.05206 (0.5000823306823515, 0.5009588685176742)
# 5.0 23.0 58.04682 (0.5800355819503357, 0.5809006943991045)
# 10.0 23.0 82.41072 (0.8237732273907101, 0.8244406745735847)
# 15.0 23.0 92.60788000000001 (0.9258491326290551, 0.926307812641721)
# 20.0 23.0 96.89128 (0.9687603130861275, 0.969064566364261)
# 25.0 23.0 98.68996 (0.9867995585980317, 0.9869988932131417)
# 30.0 23.0 99.45125999999999 (0.9944474660218185, 0.9945769740909233)
# 35.0 23.0 99.77373999999999 (0.9976953688999673, 0.9977786662574214)
# 40.0 23.0 99.90618 (0.9990345780066632, 0.9990882551156021)
# \begin{table}[tb]
# \label{tbl:the-naturally-ocurring-bingo-miracle3-20}
# \begin{tabular}{llll}
# \toprule
#  & Probability & CI lower & CI upper \\
# Decks &  &  &  \\
# \midrule
# 1 & 15.947% & 15.915% & 15.979% \\
# ...
