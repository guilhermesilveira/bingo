# %%
from tqdm import tqdm
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from bingo import *
from graph import *
from counting import *
from latex import *
from parallel import *

# %%
RUNS = 5_000_000
DECKS=[1,2,3,4,5,10,15,20,25,30,35,40]
palette = colorblind_palette(len(DECKS))

# %%
np.random.seed(56734)

# %%
# %%time

df_jokers_3_10 = quick_deck_matches_on(RUNS, decks=DECKS, accept_jokers=True, early_stop=3, discard=10)
# Out:
# CPU times: user 285 ms, sys: 710 ms, total: 996 ms
# Wall time: 4min 58s

# %%
ax, data_3_10 = print_cumulative(df_jokers_3_10, xticks=[11, 12, 13])
for i, (decks, card, values) in data_3_10.query("card==13").iterrows():
  print(decks, card, values, confidence(values * RUNS / 100, RUNS))
prob_table_to_latex(partial_card_to_prob(data_3_10.query("card==13"), RUNS), name="the-naturally-ocurring-bingo-miracle3-10")
# Out:
# 1.0 13.0 15.946079999999998 (0.159140156259908, 0.1597819670258462)
# 2.0 13.0 29.32934 (0.29289449563994835, 0.2936926219934373)
# 3.0 13.0 40.57228 (0.40529246461858176, 0.40615328025142344)
# 4.0 13.0 50.08330000000001 (0.5003947308129857, 0.5012712679069943)
# 5.0 13.0 58.01612 (0.5797285383926409, 0.5805937384285473)
# 10.0 13.0 82.37354 (0.8234011505210937, 0.8240691520145234)
# 15.0 13.0 92.62138 (0.9259843253385228, 0.9264426197248067)
# 20.0 13.0 96.89618 (0.96880942914329, 0.9691134502318032)
# 25.0 13.0 98.69731999999999 (0.9868734351986832, 0.9870722164993931)
# 30.0 13.0 99.45816 (0.9945168721273057, 0.9946455678794087)
# 35.0 13.0 99.77262 (0.9976840661972154, 0.9977675689773843)
# 40.0 13.0 99.90195999999999 (0.9989917817825789, 0.9990466514045316)
# \begin{table}[tb]
# \label{tbl:the-naturally-ocurring-bingo-miracle3-10}
# \begin{tabular}{llll}
# \toprule
#  & Probability & CI lower & CI upper \\
# Decks &  &  &  \\
# \midrule
# 1 & 15.946% & 15.914% & 15.978% \\
# ...
