# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from bingo import *
from graph import *
from counting import *
from latex import *
from signed import *
from parallel import *

# %%
RUNS = 5_000_000
DECKS=[1,2,3,4,5,10,15,20,25,30,35,40]
palette = colorblind_palette(len(DECKS))

# %%
np.random.seed(56734)

# %%
# %%time
results = quick_signed_runs(DECKS, RUNS)
results
# Out:
# CPU times: user 68.8 ms, sys: 39.6 ms, total: 108 ms
# Wall time: 26min 49s
#     Deck count  Success   Result     Runs  Probability
# 0            1  4997720  4997720  5000000     99.95440
# 1            2  4997715  4997715  5000000     99.95430
# 2            3  4997687  4997687  5000000     99.95374
# 3            4  4997646  4997646  5000000     99.95292
# 4            5  4997702  4997702  5000000     99.95404
# 5           10  4997627  4997627  5000000     99.95254
# 6           15  4997666  4997666  5000000     99.95332
# 7           20  4997701  4997701  5000000     99.95402
# 8           25  4997614  4997614  5000000     99.95228
# 9           30  4997668  4997668  5000000     99.95336
# 10          35  4997744  4997744  5000000     99.95488
# 11          40  4997632  4997632  5000000     99.95264

# %%
prop_table = print_prob_table(results)
prop_table
# Out:
#     Deck count  Success   Result     Runs  Probability    prob_l    prob_r
# 0            1  4997720  4997720  5000000     99.95440  0.999525  0.999562
# 1            2  4997715  4997715  5000000     99.95430  0.999524  0.999561
# 2            3  4997687  4997687  5000000     99.95374  0.999518  0.999556
# 3            4  4997646  4997646  5000000     99.95292  0.999510  0.999548
# 4            5  4997702  4997702  5000000     99.95404  0.999521  0.999559
# 5           10  4997627  4997627  5000000     99.95254  0.999506  0.999544
# 6           15  4997666  4997666  5000000     99.95332  0.999514  0.999552
# 7           20  4997701  4997701  5000000     99.95402  0.999521  0.999559
# 8           25  4997614  4997614  5000000     99.95228  0.999503  0.999542
# 9           30  4997668  4997668  5000000     99.95336  0.999514  0.999552
# 10          35  4997744  4997744  5000000     99.95488  0.999530  0.999567
# 11          40  4997632  4997632  5000000     99.95264  0.999507  0.999545

# %%
prob_table_to_latex(prop_table, "Prob table")
# Out:
# \begin{table}[tb]
# \label{tbl:Prob table}
# \begin{tabular}{llll}
# \toprule
#  & Probability & CI lower & CI upper \\
# Decks &  &  &  \\
# \midrule
# 1 & 99.954% & 99.952% & 99.956% \\
# 2 & 99.954% & 99.952% & 99.956% \\
# 3 & 99.954% & 99.952% & 99.956% \\
# 4 & 99.953% & 99.951% & 99.955% \\
# 5 & 99.954% & 99.952% & 99.956% \\
# 10 & 99.953% & 99.951% & 99.954% \\
# 15 & 99.953% & 99.951% & 99.955% \\
# 20 & 99.954% & 99.952% & 99.956% \\
# 25 & 99.952% & 99.950% & 99.954% \\
# 30 & 99.953% & 99.951% & 99.955% \\
# 35 & 99.955% & 99.953% & 99.957% \\
# 40 & 99.953% & 99.951% & 99.955% \\
# \bottomrule
# \end{tabular}
# \end{table}
